# %% [markdown]
# # LSTM-Based Directional Prediction of TSMC (2330)
#
# This notebook implements an end-to-end LSTM model to predict whether TSMC's stock price will move up or down using daily data from 2024.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv("TSMC_2330_2024.csv")
# Drop the first row as it appears to be ticker data, not actual data
df = df.iloc[1:].reset_index(drop=True)
# Convert columns to float
df[['Close', 'High', 'Low', 'Open', 'Volume']] = df[['Close', 'High', 'Low', 'Open', 'Volume']].astype(float)
# Add Date column assuming daily business days starting from 2024-01-01
df['Date'] = pd.date_range(start='2024-01-01', periods=len(df), freq='B')
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date').reset_index(drop=True)
df.head()
# Out:
#         Date   Open   High    Low  Close Adj Close      Volume
# 0 2024-01-01  590.0  593.0  589.0  593.0    573.75  26059058.0
# 1 2024-01-02  584.0  585.0  576.0  578.0    559.23  37106763.0
# 2 2024-01-03  580.0  581.0  577.0  580.0    561.17  15309129.0
# 3 2024-01-04  578.0  580.0  574.0  576.0     557.3  18158971.0
# 4 2024-01-05  582.0  585.0  579.0  583.0    564.07  17761275.0

# %% [markdown]
# ## 3. Feature Engineering

# %%
df['Return'] = df['Close'].pct_change()
df['MA5'] = df['Close'].rolling(window=5).mean()
df['MA10'] = df['Close'].rolling(window=10).mean()
df['Volatility'] = df['Close'].rolling(window=5).std()
df.dropna(inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12160\3450434620.py:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['Return'] = df['Close'].pct_change()

# %% [markdown]
# ## 4. Label Creation (Up / Down)

# %%
df['Target'] = (df['Close'].shift(-1) > df['Close']).astype(int)
df.dropna(inplace=True)

# %% [markdown]
# ## 5. Feature Scaling

# %%
features = ['Open', 'High', 'Low', 'Close', 'Volume',
            'Return', 'MA5', 'MA10', 'Volatility']

scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %% [markdown]
# ## 6. Sequence Construction

# %%
def create_sequences(data, target, lookback=10):
    X, y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i])
        y.append(target[i])
    return np.array(X), np.array(y)

lookback = 10
X, y = create_sequences(df[features].values, df['Target'].values, lookback)

# %% [markdown]
# ## 7. Train-Test Split

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %% [markdown]
# ## 8. LSTM Model

# %%
model = Sequential([
    LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_9 (LSTM)                   │ (None, 50)             │        12,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,051 (47.07 KB)
#  Trainable params: 12,051 (47.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 9. Model Training

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=30,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5094 - loss: 0.6995 - val_accuracy: 0.5000 - val_loss: 0.7067
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5409 - loss: 0.6901 - val_accuracy: 0.5000 - val_loss: 0.7098
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5535 - loss: 0.6910 - val_accuracy: 0.5000 - val_loss: 0.7099
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5472 - loss: 0.6874 - val_accuracy: 0.5000 - val_loss: 0.7036
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5597 - loss: 0.6915 - val_accuracy: 0.5000 - val_loss: 0.7017
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5660 - loss: 0.6855 - val_accuracy: 0.5000 - val_loss: 0.7000
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5472 - loss: 0.6896 - val_accuracy: 0.5000 - val_loss: 0.7007
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5409 - loss: 0.6917 - val_accuracy: 0.5000 - val_loss: 0.6969
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5409 - loss: 0.6888 - val_accuracy: 0.5000 - val_loss: 0.6963
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5535 - loss: 0.6914 - val_accuracy: 0.5000 - val_loss: 0.6984
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5535 - loss: 0.6884 - val_accuracy: 0.5000 - val_loss: 0.6979
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5597 - loss: 0.6835 - val_accuracy: 0.5000 - val_loss: 0.6997
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5597 - loss: 0.6876 - val_accuracy: 0.5000 - val_loss: 0.6947
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5597 - loss: 0.6855 - val_accuracy: 0.5000 - val_loss: 0.6967
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5409 - loss: 0.6922 - val_accuracy: 0.5000 - val_loss: 0.6953
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5660 - loss: 0.6891 - val_accuracy: 0.5000 - val_loss: 0.6943
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5597 - loss: 0.6861 - val_accuracy: 0.5000 - val_loss: 0.6976
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5535 - loss: 0.6855 - val_accuracy: 0.5000 - val_loss: 0.6967
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5283 - loss: 0.6884 - val_accuracy: 0.5000 - val_loss: 0.6918
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5660 - loss: 0.6827 - val_accuracy: 0.5000 - val_loss: 0.6933
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5597 - loss: 0.6863 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5472 - loss: 0.6879 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5472 - loss: 0.6875 - val_accuracy: 0.5000 - val_loss: 0.6904
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5535 - loss: 0.6821 - val_accuracy: 0.5000 - val_loss: 0.6917
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5660 - loss: 0.6862 - val_accuracy: 0.5000 - val_loss: 0.6921
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5409 - loss: 0.6831 - val_accuracy: 0.5000 - val_loss: 0.6907
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5723 - loss: 0.6838 - val_accuracy: 0.5556 - val_loss: 0.6887
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5409 - loss: 0.6945 - val_accuracy: 0.5556 - val_loss: 0.6870
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5283 - loss: 0.6920 - val_accuracy: 0.5000 - val_loss: 0.6984
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5409 - loss: 0.6877 - val_accuracy: 0.5000 - val_loss: 0.6892

# %% [markdown]
# ## 10. Evaluation

# %%
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step
# Accuracy: 0.5555555555555556
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      1.00      0.71        25
#            1       0.00      0.00      0.00        20
#
#     accuracy                           0.56        45
#    macro avg       0.28      0.50      0.36        45
# weighted avg       0.31      0.56      0.40        45
#
# Confusion Matrix:
#  [[25  0]
#  [20  0]]
# c:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## 11. Conclusion
#
# This notebook demonstrates how LSTM models can be applied to financial time-series data for directional prediction tasks.
